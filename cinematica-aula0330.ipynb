# %% [markdown]
# <a href="https://colab.research.google.com/github/souzahenrique7379608-cell/cnweb_2b2_A/blob/main/cinematica-aula0330.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Equação de romcem

# %%
import math
def caltoricelli(vzero, acel, des):
  t=2*acel*des
  v=vzero+t

# %% [markdown]
# #Função horaria da posição

# %%
def calhorariodapocição

# %% [markdown]
# #Equação de torricelli

# %% [markdown]
# #Teste de aceleração

# %% [markdown]
# #Formulas de movimnto uniformes variado (mvu)

# %%
def calvelocidadehoraria(vinical, acel, tempo):
  vh = vinical + (acel = tempo)
  return vh
