# %% [markdown]
# <a href="https://colab.research.google.com/github/souzahenrique7379608-cell/cnweb_2b2_A/blob/main/untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculadora(n1, n2, op):
